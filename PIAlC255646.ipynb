# %% [markdown]
# Exercise 3-1: Names

# %%
# Exercise 3-1: Names
names = ["Sameed", "Sadeem", "Wania", "Ahmad"]
print(names[0])
print(names[1])
print(names[2])
print(names[3])
# Out:
# Sameed
# Sadeem
# Wania
# Ahmad

# %% [markdown]
# Exercise 3-2: Greetings

# %%
greeting = "Hello, {}! How are you today?"
print(greeting.format(names[0]))
print(greeting.format(names[1]))
print(greeting.format(names[2]))
print(greeting.format(names[3]))
# Out:
# Hello, Sameed! How are you today?
# Hello, Sadeem! How are you today?
# Hello, Wania! How are you today?
# Hello, Ahmad! How are you today?

# %% [markdown]
# # Exercise 3-3: Your Own List

# %%
transportations = ["car", "motorcycle", "bicycle"]
print(f"I would like to own a Tesla {transportations[0]}.")
print(f"I would like to ride a Harley-Davidson {transportations[1]}.")
print(f"I enjoy riding a {transportations[2]} on weekends.")
# Out:
# I would like to own a Tesla car.
# I would like to ride a Harley-Davidson motorcycle.
# I enjoy riding a bicycle on weekends.

# %% [markdown]
# # Exercise 3-4: Guest List

# %%
guests = ["Sameed", "Sadeem", "Wania", "Muhammad Ahmad"]
print(f"Dear {guests[0]}, please join me for dinner.")
print(f"Dear {guests[1]}, please join me for dinner.")
print(f"Dear {guests[2]}, please join me for dinner.")
print(f"Dear {guests[3]}, please join me for dinner.")
# Out:
# Dear Sameed, please join me for dinner.
# Dear Sadeem, please join me for dinner.
# Dear Wania, please join me for dinner.
# Dear Muhammad Ahmad, please join me for dinner.

# %% [markdown]
# # Exercise 3-5: Changing Guest List

# %%
print(f"Unfortunately, {guests[3]} can't make it to dinner.")
guests[3] = "Hadeed"
print(f"Dear {guests[0]}, please join me for dinner.")
print(f"Dear {guests[1]}, please join me for dinner.")
print(f"Dear {guests[2]}, please join me for dinner.")
print(f"Dear {guests[3]}, please join me for dinner.")
# Out:
# Unfortunately, Muhammad Ahmad can't make it to dinner.
# Dear Sameed, please join me for dinner.
# Dear Sadeem, please join me for dinner.
# Dear Wania, please join me for dinner.
# Dear Hadeed, please join me for dinner.

# %% [markdown]
# # Exercise 3-6: More Guests

# %%
print("I found a bigger table, so I'm inviting more guests!")
guests.insert(2, "Tahreem")
guests.append("Aiza")
print(f"Dear {guests[0]}, please join me for dinner.")
print(f"Dear {guests[1]}, please join me for dinner.")
print(f"Dear {guests[2]}, please join me for dinner.")
print(f"Dear {guests[3]}, please join me for dinner.")
print(f"Dear {guests[4]}, please join me for dinner.")
print(f"Dear {guests[5]}, please join me for dinner.")
# Out:
# I found a bigger table, so I'm inviting more guests!
# Dear Sameed, please join me for dinner.
# Dear Sadeem, please join me for dinner.
# Dear Tahreem, please join me for dinner.
# Dear Wania, please join me for dinner.
# Dear Hadeed, please join me for dinner.
# Dear Aiza, please join me for dinner.

# %% [markdown]
# # Exercise 3-7: Shrinking Guest List

# %%
removed_guests = []
print("I can invite only two people for dinner.")
sorry_message = "I'm sorry, {}. I can't invite you to dinner."
removed_guests.append(guests.pop())
print(sorry_message.format(removed_guests[-1]))
removed_guests.append(guests.pop())
print(sorry_message.format(removed_guests[-1]))
removed_guests.append(guests.pop())
print(sorry_message.format(removed_guests[-1]))
removed_guests.append(guests.pop())
print(sorry_message.format(removed_guests[-1]))
print(f"Dear {guests[0]}, you're still invited to dinner.")
print(f"Dear {guests[1]}, you're still invited to dinner.")
del guests[0]
del guests[0]
print(guests)
print("Removed guests:", removed_guests)
# Out:
# I can invite only two people for dinner.
# I'm sorry, Aiza. I can't invite you to dinner.
# I'm sorry, Hadeed. I can't invite you to dinner.
# I'm sorry, Wania. I can't invite you to dinner.
# I'm sorry, Tahreem. I can't invite you to dinner.
# Dear Sameed, you're still invited to dinner.
# Dear Sadeem, you're still invited to dinner.
# []
# Removed guests: ['Aiza', 'Hadeed', 'Wania', 'Tahreem']

# %% [markdown]
# # Exercise 3-8: Seeing the World

# %%
places = ["Oman", "UAE", "Japan", "China", "UK"]
print("Orignal List",places)
print("Sorted List Ascending Order",sorted(places))
print("Orignal List",places)
print("Sorted List Decending Order",sorted(places, reverse=True))
print("Orignal List",places)
print()
places.reverse()
print(places)
places.reverse()
print(places)
places.sort()
print(places)
places.sort(reverse=True)
print(places)
# Out:
# Orignal List ['Oman', 'UAE', 'Japan', 'China', 'UK']
# Sorted List Ascending Order ['China', 'Japan', 'Oman', 'UAE', 'UK']
# Orignal List ['Oman', 'UAE', 'Japan', 'China', 'UK']
# Sorted List Decending Order ['UK', 'UAE', 'Oman', 'Japan', 'China']
# Orignal List ['Oman', 'UAE', 'Japan', 'China', 'UK']
#
# ['UK', 'China', 'Japan', 'UAE', 'Oman']
# ['Oman', 'UAE', 'Japan', 'China', 'UK']
# ['China', 'Japan', 'Oman', 'UAE', 'UK']
# ['UK', 'UAE', 'Oman', 'Japan', 'China']

# %% [markdown]
# # Exercise 3-9: Dinner Guests

# %%
# Exercise 3-9: Dinner Guests
print(f"I'm inviting {len(guests)} people to dinner.")
# Out:
# I'm inviting 0 people to dinner.

# %% [markdown]
# # Exercise 3-10: Every Function

# %%
mountains = ["Naran", "Thandiyani", "Nathiya Gali"]
print("Print All Favourite Places",mountains)
print("Print All Favourite Place on 0 Index",mountains[0])
mountains.append("Hunza")
print("Add New Place At the End Of List",mountains)
mountains.insert(1, "Khujrab")
print("Add An Other New Place At the End Of List",mountains)
mountains.remove("Naran")
print(mountains)
popped_mountain = mountains.pop()
print("Deleted Last Index ",popped_mountain)
print("Remaining List Of Index",mountains)
# Out:
# Print All Favourite Places ['Naran', 'Thandiyani', 'Nathiya Gali']
# Print All Favourite Place on 0 Index Naran
# Add New Place At the End Of List ['Naran', 'Thandiyani', 'Nathiya Gali', 'Hunza']
# Add An Other New Place At the End Of List ['Naran', 'Khujrab', 'Thandiyani', 'Nathiya Gali', 'Hunza']
# ['Khujrab', 'Thandiyani', 'Nathiya Gali', 'Hunza']
# Deleted Last Index  Hunza
# Remaining List Of Index ['Khujrab', 'Thandiyani', 'Nathiya Gali']

# %% [markdown]
# # Exercise 3-11: Intentional Error

# %%
#print(mountains[10])

# %%
try:
    print(mountains[10])
except IndexError as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: list index out of range
